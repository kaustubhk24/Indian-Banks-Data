# %%
import os
import json
import urllib.request
import requests 
from IPython.display import clear_output

from collections import OrderedDict
from itertools import islice
from openpyxl import load_workbook

#with open('IFCB2009_02.xlsx') as f:
def checkTuple(row,index):
    if index < len(row):
        if row[index]!=None:
            return row[index]
        else:
            return blank_space
    else:
        return blank_space
    
    
def getToFile(url,file_name):
    url="https://ifsc.razorpay.com/"+url;
    print(url)
    response=requests.get(url) 
    return response.json()
    
#     f=open(file_name.replace('xlsx','json'),"a")
#     f.write(response.json())



    
    
def start(list1,file_name):
    complete=[]
    bank=getToFile(list1[0],file_name)
    print(bank['BANK'])
    for url1 in list1:
        complete.append(getToFile(url1,file_name))
    with open(bank['BANK']+".json", 'w+') as outfile:
        json.dump(complete, outfile, indent=4, sort_keys=True)
        os.rename(file_name,bank['BANK'].replace(' ','_')+".xlsx")

        
        
        
def ExcelToJson(file_name):        
    wb = load_workbook(file_name)
    sheet = wb[wb.sheetnames[0]]
    json_file_name=""
    banks_list = []
    for row in islice(sheet.values, 1, sheet.max_row):
        banks = OrderedDict()
        banks_list.append(checkTuple(row,1))
    j = json.dumps(banks_list, indent = 1)
    start(banks_list,file_name)
    
    



ExcelToJson("IFCB2009_82.xlsx")
# Out:
# https://ifsc.razorpay.com/SBIN0011909
# State Bank of India
# https://ifsc.razorpay.com/SBIN0011909
# https://ifsc.razorpay.com/SBIN0011908
# https://ifsc.razorpay.com/SBIN0011907
# https://ifsc.razorpay.com/SBIN0011906
# https://ifsc.razorpay.com/SBIN0011905
# https://ifsc.razorpay.com/SBIN0011904
# https://ifsc.razorpay.com/SBIN0011903
# https://ifsc.razorpay.com/SBIN0011902
# https://ifsc.razorpay.com/SBIN0011901
# https://ifsc.razorpay.com/SBIN0011900
# https://ifsc.razorpay.com/SBIN0011899
# https://ifsc.razorpay.com/SBIN0011898
# https://ifsc.razorpay.com/SBIN0011897
# https://ifsc.razorpay.com/SBIN0011896
# https://ifsc.razorpay.com/SBIN0011895
# https://ifsc.razorpay.com/SBIN0011894
# https://ifsc.razorpay.com/SBIN0011893
# https://ifsc.razorpay.com/SBIN0011892
# https://ifsc.razorpay.com/SBIN0011891
# https://ifsc.razorpay.com/SBIN0011890
# https://ifsc.razorpay.com/SBIN0011889
# https://ifsc.razorpay.com/SBIN0011888
# https://ifsc.razorpay.com/SBIN0011887
# https://ifsc.razorpay.com/SBIN0011886
# https://ifsc.razorpay.com/SBIN0011885
# https://ifsc.razorpay.com/SBIN0011884
# https://ifsc.razorpay.com/SBIN0011883
# https://ifsc.razorpay.com/SBIN0011882
# https://ifsc.razorpay.com/SBIN0011881
# https://ifsc.razorpay.com/SBIN0011880
# https://ifsc.razorpay.com/SBIN0011879
# https://ifsc.razorpay.com/SBIN0011878
# https://ifsc.razorpay.com/SBIN0011877
# https://ifsc.razorpay.com/SBIN0011876
# https://ifsc.razorpay.com/SBIN0011875
# https://ifsc.razorpay.com/SBIN0011874
# https://ifsc.razorpay.com/SBIN0011873
# https://ifsc.razorpay.com/SBIN0011872
# https://ifsc.razorpay.com/SBIN0011871
# https://ifsc.razorpay.com/SBIN0011870
# https://ifsc.razorpay.com/SBIN0011869
# https://ifsc.razorpay.com/SBIN0011868
# https://ifsc.razorpay.com/SBIN0011867
# https://ifsc.razorpay.com/SBIN0011866
# https://ifsc.razorpay.com/SBIN0011865
# https://ifsc.razorpay.com/SBIN0011864
# https://ifsc.razorpay.com/SBIN0011863
# https://ifsc.razorpay.com/SBIN0011862
# https://ifsc.razorpay.com/SBIN0011861
# https://ifsc.razorpay.com/SBIN0011860
# https://ifsc.razorpay.com/SBIN0011859
# https://ifsc.razorpay.com/SBIN0011858
# https://ifsc.razorpay.com/SBIN0011857
# https://ifsc.razorpay.com/SBIN0011856
# https://ifsc.razorpay.com/SBIN0011855
# https://ifsc.razorpay.com/SBIN0011854
# https://ifsc.razorpay.com/SBIN0011853
# https://ifsc.razorpay.com/SBIN0011852
# https://ifsc.razorpay.com/SBIN0011851
# https://ifsc.razorpay.com/SBIN0011850
# https://ifsc.razorpay.com/SBIN0011849
# https://ifsc.razorpay.com/SBIN0011848
# https://ifsc.razorpay.com/SBIN0011847
# https://ifsc.razorpay.com/SBIN0011846
# https://ifsc.razorpay.com/SBIN0011845
# https://ifsc.razorpay.com/SBIN0011844
# https://ifsc.razorpay.com/SBIN0011843
# https://ifsc.razorpay.com/SBIN0011842
# https://ifsc.razorpay.com/SBIN0011841
# https://ifsc.razorpay.com/SBIN0011840
# https://ifsc.razorpay.com/SBIN0011839
# https://ifsc.razorpay.com/SBIN0011838
# https://ifsc.razorpay.com/SBIN0011837
# https://ifsc.razorpay.com/SBIN0011836
# https://ifsc.razorpay.com/SBIN0011835
# https://ifsc.razorpay.com/SBIN0011834
# https://ifsc.razorpay.com/SBIN0011833
# https://ifsc.razorpay.com/SBIN0011832
# https://ifsc.razorpay.com/SBIN0011831
# https://ifsc.razorpay.com/SBIN0011830
# https://ifsc.razorpay.com/SBIN0011829
# https://ifsc.razorpay.com/SBIN0011828
# https://ifsc.razorpay.com/SBIN0011827
# https://ifsc.razorpay.com/SBIN0011826
# https://ifsc.razorpay.com/SBIN0011825
# https://ifsc.razorpay.com/SBIN0011824
# https://ifsc.razorpay.com/SBIN0011823
# https://ifsc.razorpay.com/SBIN0011822
# https://ifsc.razorpay.com/SBIN0011821
# https://ifsc.razorpay.com/SBIN0011820
# https://ifsc.razorpay.com/SBIN0011819
# https://ifsc.razorpay.com/SBIN0011818
# https://ifsc.razorpay.com/SBIN0011817
# https://ifsc.razorpay.com/SBIN0011816
# https://ifsc.razorpay.com/SBIN0011815
# https://ifsc.razorpay.com/SBIN0011814
# https://ifsc.razorpay.com/SBIN0011813
# https://ifsc.razorpay.com/SBIN0011812
# https://ifsc.razorpay.com/SBIN0011810
# https://ifsc.razorpay.com/SBIN0011809
# https://ifsc.razorpay.com/SBIN0011808
# https://ifsc.razorpay.com/SBIN0011807
# https://ifsc.razorpay.com/SBIN0011806
# https://ifsc.razorpay.com/SBIN0011805
# https://ifsc.razorpay.com/SBIN0011804
# https://ifsc.razorpay.com/SBIN0011803
# https://ifsc.razorpay.com/SBIN0011802
# https://ifsc.razorpay.com/SBIN0011801
# https://ifsc.razorpay.com/SBIN0011800
# https://ifsc.razorpay.com/SBIN0011799
# https://ifsc.razorpay.com/SBIN0011798
# https://ifsc.razorpay.com/SBIN0011797
# https://ifsc.razorpay.com/SBIN0011796
# https://ifsc.razorpay.com/SBIN0011795
# https://ifsc.razorpay.com/SBIN0011794
# https://ifsc.razorpay.com/SBIN0011793
# https://ifsc.razorpay.com/SBIN0011792
# https://ifsc.razorpay.com/SBIN0011791
# https://ifsc.razorpay.com/SBIN0011790
# https://ifsc.razorpay.com/SBIN0011789
# https://ifsc.razorpay.com/SBIN0011788
# https://ifsc.razorpay.com/SBIN0011787
# https://ifsc.razorpay.com/SBIN0011786
# https://ifsc.razorpay.com/SBIN0011785
# https://ifsc.razorpay.com/SBIN0011784
# https://ifsc.razorpay.com/SBIN0011783
# https://ifsc.razorpay.com/SBIN0011782
# https://ifsc.razorpay.com/SBIN0011781
# https://ifsc.razorpay.com/SBIN0011780
# https://ifsc.razorpay.com/SBIN0011779
# https://ifsc.razorpay.com/SBIN0011778
# https://ifsc.razorpay.com/SBIN0011777
# https://ifsc.razorpay.com/SBIN0011776
# https://ifsc.razorpay.com/SBIN0011775
# https://ifsc.razorpay.com/SBIN0011774
# https://ifsc.razorpay.com/SBIN0011772
# https://ifsc.razorpay.com/SBIN0011771
# https://ifsc.razorpay.com/SBIN0011770
# https://ifsc.razorpay.com/SBIN0011769
# https://ifsc.razorpay.com/SBIN0011768
# https://ifsc.razorpay.com/SBIN0011767
# https://ifsc.razorpay.com/SBIN0011766
# https://ifsc.razorpay.com/SBIN0011765
# https://ifsc.razorpay.com/SBIN0011764
# https://ifsc.razorpay.com/SBIN0011763
# https://ifsc.razorpay.com/SBIN0011762
# https://ifsc.razorpay.com/SBIN0011761
# https://ifsc.razorpay.com/SBIN0011760
# https://ifsc.razorpay.com/SBIN0011759
# https://ifsc.razorpay.com/SBIN0011758
# https://ifsc.razorpay.com/SBIN0011757
# https://ifsc.razorpay.com/SBIN0011756
# https://ifsc.razorpay.com/SBIN0011755
# https://ifsc.razorpay.com/SBIN0011754
# https://ifsc.razorpay.com/SBIN0011753
# https://ifsc.razorpay.com/SBIN0011752
# https://ifsc.razorpay.com/SBIN0011751
# https://ifsc.razorpay.com/SBIN0011750
# https://ifsc.razorpay.com/SBIN0011749
# https://ifsc.razorpay.com/SBIN0011748
# https://ifsc.razorpay.com/SBIN0011747
# https://ifsc.razorpay.com/SBIN0011746
# https://ifsc.razorpay.com/SBIN0011745
# https://ifsc.razorpay.com/SBIN0011744
# https://ifsc.razorpay.com/SBIN0011743
# https://ifsc.razorpay.com/SBIN0011742
# https://ifsc.razorpay.com/SBIN0011741
# https://ifsc.razorpay.com/SBIN0011740
# https://ifsc.razorpay.com/SBIN0011739
# https://ifsc.razorpay.com/SBIN0011738
# https://ifsc.razorpay.com/SBIN0011737
# https://ifsc.razorpay.com/SBIN0011736
# https://ifsc.razorpay.com/SBIN0011733
# https://ifsc.razorpay.com/SBIN0011732
# https://ifsc.razorpay.com/SBIN0011731
# https://ifsc.razorpay.com/SBIN0011730
# https://ifsc.razorpay.com/SBIN0011729
# https://ifsc.razorpay.com/SBIN0011728
# https://ifsc.razorpay.com/SBIN0011727
# https://ifsc.razorpay.com/SBIN0011726
# https://ifsc.razorpay.com/SBIN0011725
# https://ifsc.razorpay.com/SBIN0011724
# https://ifsc.razorpay.com/SBIN0011723
# https://ifsc.razorpay.com/SBIN0011722
# https://ifsc.razorpay.com/SBIN0011721
# https://ifsc.razorpay.com/SBIN0011720
# https://ifsc.razorpay.com/SBIN0011719
# https://ifsc.razorpay.com/SBIN0011718
# https://ifsc.razorpay.com/SBIN0011717
# https://ifsc.razorpay.com/SBIN0011716
# https://ifsc.razorpay.com/SBIN0011715
# https://ifsc.razorpay.com/SBIN0011714
# https://ifsc.razorpay.com/SBIN0011713
# https://ifsc.razorpay.com/SBIN0011712
# https://ifsc.razorpay.com/SBIN0011711
# https://ifsc.razorpay.com/SBIN0011710
# https://ifsc.razorpay.com/SBIN0011709
# https://ifsc.razorpay.com/SBIN0011708
# https://ifsc.razorpay.com/SBIN0011707
# https://ifsc.razorpay.com/SBIN0011706
# https://ifsc.razorpay.com/SBIN0011705
# https://ifsc.razorpay.com/SBIN0011704
# https://ifsc.razorpay.com/SBIN0011703
# https://ifsc.razorpay.com/SBIN0011702
# https://ifsc.razorpay.com/SBIN0011701
# https://ifsc.razorpay.com/SBIN0011699
# https://ifsc.razorpay.com/SBIN0011698
# https://ifsc.razorpay.com/SBIN0011697
# https://ifsc.razorpay.com/SBIN0011696
# https://ifsc.razorpay.com/SBIN0011695
# https://ifsc.razorpay.com/SBIN0011694
# https://ifsc.razorpay.com/SBIN0011693
# https://ifsc.razorpay.com/SBIN0011692
# https://ifsc.razorpay.com/SBIN0011691
# https://ifsc.razorpay.com/SBIN0011690
# https://ifsc.razorpay.com/SBIN0011689
# https://ifsc.razorpay.com/SBIN0011688
# https://ifsc.razorpay.com/SBIN0011687
# https://ifsc.razorpay.com/SBIN0011680
# https://ifsc.razorpay.com/SBIN0011679
# https://ifsc.razorpay.com/SBIN0011678
# https://ifsc.razorpay.com/SBIN0011677
# https://ifsc.razorpay.com/SBIN0011676
# https://ifsc.razorpay.com/SBIN0011675
# https://ifsc.razorpay.com/SBIN0011674
# https://ifsc.razorpay.com/SBIN0011673
# https://ifsc.razorpay.com/SBIN0011672
# https://ifsc.razorpay.com/SBIN0011670
# https://ifsc.razorpay.com/SBIN0011669
# https://ifsc.razorpay.com/SBIN0011668
# https://ifsc.razorpay.com/SBIN0011667
# https://ifsc.razorpay.com/SBIN0011666
# https://ifsc.razorpay.com/SBIN0011665
# https://ifsc.razorpay.com/SBIN0011664
# https://ifsc.razorpay.com/SBIN0011663
# https://ifsc.razorpay.com/SBIN0011662
# https://ifsc.razorpay.com/SBIN0011661
# https://ifsc.razorpay.com/SBIN0011660
# https://ifsc.razorpay.com/SBIN0011659
# https://ifsc.razorpay.com/SBIN0011658
# https://ifsc.razorpay.com/SBIN0011657
# https://ifsc.razorpay.com/SBIN0011656
# https://ifsc.razorpay.com/SBIN0011655
# https://ifsc.razorpay.com/SBIN0011654
# https://ifsc.razorpay.com/SBIN0011653
# https://ifsc.razorpay.com/SBIN0011652
# https://ifsc.razorpay.com/SBIN0011651
# https://ifsc.razorpay.com/SBIN0011650
# https://ifsc.razorpay.com/SBIN0011649
# https://ifsc.razorpay.com/SBIN0011648
# https://ifsc.razorpay.com/SBIN0011647
# https://ifsc.razorpay.com/SBIN0011646
# https://ifsc.razorpay.com/SBIN0011645
# https://ifsc.razorpay.com/SBIN0011644
# https://ifsc.razorpay.com/SBIN0011643
# https://ifsc.razorpay.com/SBIN0011642
# https://ifsc.razorpay.com/SBIN0011641
# https://ifsc.razorpay.com/SBIN0011640
# https://ifsc.razorpay.com/SBIN0011639
# https://ifsc.razorpay.com/SBIN0011638
# https://ifsc.razorpay.com/SBIN0011637
# https://ifsc.razorpay.com/SBIN0011636
# https://ifsc.razorpay.com/SBIN0011635
# https://ifsc.razorpay.com/SBIN0011634
# https://ifsc.razorpay.com/SBIN0011633
# https://ifsc.razorpay.com/SBIN0011632
# https://ifsc.razorpay.com/SBIN0011631
# https://ifsc.razorpay.com/SBIN0011630
# https://ifsc.razorpay.com/SBIN0011629
# https://ifsc.razorpay.com/SBIN0011628
# https://ifsc.razorpay.com/SBIN0011627
# https://ifsc.razorpay.com/SBIN0011626
# https://ifsc.razorpay.com/SBIN0011625
# https://ifsc.razorpay.com/SBIN0011624
# https://ifsc.razorpay.com/SBIN0011623
# https://ifsc.razorpay.com/SBIN0011622
# https://ifsc.razorpay.com/SBIN0011621
# https://ifsc.razorpay.com/SBIN0011620
# https://ifsc.razorpay.com/SBIN0011619
# https://ifsc.razorpay.com/SBIN0011618
# https://ifsc.razorpay.com/SBIN0011617
# https://ifsc.razorpay.com/SBIN0011616
# https://ifsc.razorpay.com/SBIN0011615
# https://ifsc.razorpay.com/SBIN0011614
# https://ifsc.razorpay.com/SBIN0011613
# https://ifsc.razorpay.com/SBIN0011612
# https://ifsc.razorpay.com/SBIN0011611
# https://ifsc.razorpay.com/SBIN0011610
# https://ifsc.razorpay.com/SBIN0011609
# https://ifsc.razorpay.com/SBIN0011608
# https://ifsc.razorpay.com/SBIN0011607
# https://ifsc.razorpay.com/SBIN0011606
# https://ifsc.razorpay.com/SBIN0011605
# https://ifsc.razorpay.com/SBIN0011604
# https://ifsc.razorpay.com/SBIN0011603
# https://ifsc.razorpay.com/SBIN0011602
# https://ifsc.razorpay.com/SBIN0011601
# https://ifsc.razorpay.com/SBIN0011600
# https://ifsc.razorpay.com/SBIN0011599
# https://ifsc.razorpay.com/SBIN0011598
# https://ifsc.razorpay.com/SBIN0011597
# https://ifsc.razorpay.com/SBIN0011596
# https://ifsc.razorpay.com/SBIN0011595
# https://ifsc.razorpay.com/SBIN0011594
# https://ifsc.razorpay.com/SBIN0011593
# https://ifsc.razorpay.com/SBIN0011592
# https://ifsc.razorpay.com/SBIN0011591
# https://ifsc.razorpay.com/SBIN0011590
# https://ifsc.razorpay.com/SBIN0011589
# https://ifsc.razorpay.com/SBIN0011588
# https://ifsc.razorpay.com/SBIN0011587
# https://ifsc.razorpay.com/SBIN0011586
# https://ifsc.razorpay.com/SBIN0011585
# https://ifsc.razorpay.com/SBIN0011584
# https://ifsc.razorpay.com/SBIN0011583
# https://ifsc.razorpay.com/SBIN0011582
# https://ifsc.razorpay.com/SBIN0011581
# https://ifsc.razorpay.com/SBIN0011580
# https://ifsc.razorpay.com/SBIN0011579
# https://ifsc.razorpay.com/SBIN0011578
# https://ifsc.razorpay.com/SBIN0011577
# https://ifsc.razorpay.com/SBIN0011576
# https://ifsc.razorpay.com/SBIN0011575
# https://ifsc.razorpay.com/SBIN0011574
# https://ifsc.razorpay.com/SBIN0011573
# https://ifsc.razorpay.com/SBIN0011572
# https://ifsc.razorpay.com/SBIN0011571
# https://ifsc.razorpay.com/SBIN0011569
# https://ifsc.razorpay.com/SBIN0011568
# https://ifsc.razorpay.com/SBIN0011567
# https://ifsc.razorpay.com/SBIN0011566
# https://ifsc.razorpay.com/SBIN0011565
# https://ifsc.razorpay.com/SBIN0011564
# https://ifsc.razorpay.com/SBIN0011563
# https://ifsc.razorpay.com/SBIN0011562
# https://ifsc.razorpay.com/SBIN0011561
# https://ifsc.razorpay.com/SBIN0011560
# https://ifsc.razorpay.com/SBIN0011559
# https://ifsc.razorpay.com/SBIN0011558
# https://ifsc.razorpay.com/SBIN0011557
# https://ifsc.razorpay.com/SBIN0011556
# https://ifsc.razorpay.com/SBIN0011555
# https://ifsc.razorpay.com/SBIN0011554
# https://ifsc.razorpay.com/SBIN0011553
# https://ifsc.razorpay.com/SBIN0011552
# https://ifsc.razorpay.com/SBIN0011551
# https://ifsc.razorpay.com/SBIN0011550
# https://ifsc.razorpay.com/SBIN0011549
# https://ifsc.razorpay.com/SBIN0011548
# https://ifsc.razorpay.com/SBIN0011547
# https://ifsc.razorpay.com/SBIN0011546
# https://ifsc.razorpay.com/SBIN0011545
# https://ifsc.razorpay.com/SBIN0011544
# https://ifsc.razorpay.com/SBIN0011543
# https://ifsc.razorpay.com/SBIN0011542
# https://ifsc.razorpay.com/SBIN0011541
# https://ifsc.razorpay.com/SBIN0011540
# https://ifsc.razorpay.com/SBIN0011539
# https://ifsc.razorpay.com/SBIN0011538
# https://ifsc.razorpay.com/SBIN0011537
# https://ifsc.razorpay.com/SBIN0011536
# https://ifsc.razorpay.com/SBIN0011535
# https://ifsc.razorpay.com/SBIN0011534
# https://ifsc.razorpay.com/SBIN0011533
# https://ifsc.razorpay.com/SBIN0011532
# https://ifsc.razorpay.com/SBIN0011531
# https://ifsc.razorpay.com/SBIN0011530
# https://ifsc.razorpay.com/SBIN0011529
# https://ifsc.razorpay.com/SBIN0011528
# https://ifsc.razorpay.com/SBIN0011527
# https://ifsc.razorpay.com/SBIN0011526
# https://ifsc.razorpay.com/SBIN0011525
# https://ifsc.razorpay.com/SBIN0011523
# https://ifsc.razorpay.com/SBIN0011522
# https://ifsc.razorpay.com/SBIN0011521
# https://ifsc.razorpay.com/SBIN0011520
# https://ifsc.razorpay.com/SBIN0011519
# https://ifsc.razorpay.com/SBIN0011518
# https://ifsc.razorpay.com/SBIN0011517
# https://ifsc.razorpay.com/SBIN0011516
# https://ifsc.razorpay.com/SBIN0011515
# https://ifsc.razorpay.com/SBIN0011514
# https://ifsc.razorpay.com/SBIN0011512
# https://ifsc.razorpay.com/SBIN0011511
# https://ifsc.razorpay.com/SBIN0011510
# https://ifsc.razorpay.com/SBIN0011509
# https://ifsc.razorpay.com/SBIN0011508
# https://ifsc.razorpay.com/SBIN0011507
# https://ifsc.razorpay.com/SBIN0011506
# https://ifsc.razorpay.com/SBIN0011505
# https://ifsc.razorpay.com/SBIN0011504
# https://ifsc.razorpay.com/SBIN0011503
# https://ifsc.razorpay.com/SBIN0011502
# https://ifsc.razorpay.com/SBIN0011501
# https://ifsc.razorpay.com/SBIN0011500
# https://ifsc.razorpay.com/SBIN0011499
# https://ifsc.razorpay.com/SBIN0011498
# https://ifsc.razorpay.com/SBIN0011496
# https://ifsc.razorpay.com/SBIN0011495
# https://ifsc.razorpay.com/SBIN0011494
# https://ifsc.razorpay.com/SBIN0011493
# https://ifsc.razorpay.com/SBIN0011492
# https://ifsc.razorpay.com/SBIN0011491
# https://ifsc.razorpay.com/SBIN0011490
# https://ifsc.razorpay.com/SBIN0011489
# https://ifsc.razorpay.com/SBIN0011488
# https://ifsc.razorpay.com/SBIN0011487
# https://ifsc.razorpay.com/SBIN0011486
# https://ifsc.razorpay.com/SBIN0011485
# https://ifsc.razorpay.com/SBIN0011484
# https://ifsc.razorpay.com/SBIN0011483
# https://ifsc.razorpay.com/SBIN0011482
# https://ifsc.razorpay.com/SBIN0011481
# https://ifsc.razorpay.com/SBIN0011480
# https://ifsc.razorpay.com/SBIN0011479
# https://ifsc.razorpay.com/SBIN0011478
# https://ifsc.razorpay.com/SBIN0011477
# https://ifsc.razorpay.com/SBIN0011476
# https://ifsc.razorpay.com/SBIN0011475
# https://ifsc.razorpay.com/SBIN0011474
# https://ifsc.razorpay.com/SBIN0011473
# https://ifsc.razorpay.com/SBIN0011472
# https://ifsc.razorpay.com/SBIN0011471
# https://ifsc.razorpay.com/SBIN0011470
# https://ifsc.razorpay.com/SBIN0011469
# https://ifsc.razorpay.com/SBIN0011468
# https://ifsc.razorpay.com/SBIN0011467
# https://ifsc.razorpay.com/SBIN0011466
# https://ifsc.razorpay.com/SBIN0011465
# https://ifsc.razorpay.com/SBIN0011464
# https://ifsc.razorpay.com/SBIN0011463
# https://ifsc.razorpay.com/SBIN0011462
# https://ifsc.razorpay.com/SBIN0011461
# https://ifsc.razorpay.com/SBIN0011460
# https://ifsc.razorpay.com/SBIN0011459
# https://ifsc.razorpay.com/SBIN0011458
# https://ifsc.razorpay.com/SBIN0011457
# https://ifsc.razorpay.com/SBIN0011456
# https://ifsc.razorpay.com/SBIN0011455
# https://ifsc.razorpay.com/SBIN0011454
# https://ifsc.razorpay.com/SBIN0011453
# https://ifsc.razorpay.com/SBIN0011452
# https://ifsc.razorpay.com/SBIN0011451
# https://ifsc.razorpay.com/SBIN0011450
# https://ifsc.razorpay.com/SBIN0011449
# https://ifsc.razorpay.com/SBIN0011448
# https://ifsc.razorpay.com/SBIN0011447
# https://ifsc.razorpay.com/SBIN0011446
# https://ifsc.razorpay.com/SBIN0011445
# https://ifsc.razorpay.com/SBIN0011444
# https://ifsc.razorpay.com/SBIN0011443
# https://ifsc.razorpay.com/SBIN0011442
# https://ifsc.razorpay.com/SBIN0011441
# https://ifsc.razorpay.com/SBIN0011440
# https://ifsc.razorpay.com/SBIN0011439
# https://ifsc.razorpay.com/SBIN0011438
# https://ifsc.razorpay.com/SBIN0011436
# https://ifsc.razorpay.com/SBIN0011435
# https://ifsc.razorpay.com/SBIN0011434
# https://ifsc.razorpay.com/SBIN0011433
# https://ifsc.razorpay.com/SBIN0011432
# https://ifsc.razorpay.com/SBIN0011431
# https://ifsc.razorpay.com/SBIN0011430
# https://ifsc.razorpay.com/SBIN0011428
# https://ifsc.razorpay.com/SBIN0011427
# https://ifsc.razorpay.com/SBIN0011426
# https://ifsc.razorpay.com/SBIN0011425
# https://ifsc.razorpay.com/SBIN0011424
# https://ifsc.razorpay.com/SBIN0011423
# https://ifsc.razorpay.com/SBIN0011422
# https://ifsc.razorpay.com/SBIN0011421
# https://ifsc.razorpay.com/SBIN0011420
# https://ifsc.razorpay.com/SBIN0011419
# https://ifsc.razorpay.com/SBIN0011418
# https://ifsc.razorpay.com/SBIN0011417
# https://ifsc.razorpay.com/SBIN0011416
# https://ifsc.razorpay.com/SBIN0011415
# https://ifsc.razorpay.com/SBIN0011414
# https://ifsc.razorpay.com/SBIN0011413
# https://ifsc.razorpay.com/SBIN0011412
# https://ifsc.razorpay.com/SBIN0011411
# https://ifsc.razorpay.com/SBIN0011410
# https://ifsc.razorpay.com/SBIN0011409
# https://ifsc.razorpay.com/SBIN0011408
# https://ifsc.razorpay.com/SBIN0011407
# https://ifsc.razorpay.com/SBIN0011406
# https://ifsc.razorpay.com/SBIN0011405
# https://ifsc.razorpay.com/SBIN0011404
# https://ifsc.razorpay.com/SBIN0011403
# https://ifsc.razorpay.com/SBIN0011402
# https://ifsc.razorpay.com/SBIN0011401
# https://ifsc.razorpay.com/SBIN0011400
# https://ifsc.razorpay.com/SBIN0011399
# https://ifsc.razorpay.com/SBIN0011398
# https://ifsc.razorpay.com/SBIN0011397
# https://ifsc.razorpay.com/SBIN0011396
# https://ifsc.razorpay.com/SBIN0011395
# https://ifsc.razorpay.com/SBIN0011394
# https://ifsc.razorpay.com/SBIN0011393
# https://ifsc.razorpay.com/SBIN0011392
# https://ifsc.razorpay.com/SBIN0011391
# https://ifsc.razorpay.com/SBIN0011390
# https://ifsc.razorpay.com/SBIN0011389
# https://ifsc.razorpay.com/SBIN0011388
# https://ifsc.razorpay.com/SBIN0011387
# https://ifsc.razorpay.com/SBIN0011386
# https://ifsc.razorpay.com/SBIN0011385
# https://ifsc.razorpay.com/SBIN0011384
# https://ifsc.razorpay.com/SBIN0011383
# https://ifsc.razorpay.com/SBIN0011382
# https://ifsc.razorpay.com/SBIN0011381
# https://ifsc.razorpay.com/SBIN0011380
# https://ifsc.razorpay.com/SBIN0011379
# https://ifsc.razorpay.com/SBIN0011378
# https://ifsc.razorpay.com/SBIN0011377
# https://ifsc.razorpay.com/SBIN0011376
# https://ifsc.razorpay.com/SBIN0011375
# https://ifsc.razorpay.com/SBIN0011374
# https://ifsc.razorpay.com/SBIN0011373
# https://ifsc.razorpay.com/SBIN0011372
# https://ifsc.razorpay.com/SBIN0011371
# https://ifsc.razorpay.com/SBIN0011370
# https://ifsc.razorpay.com/SBIN0011369
# https://ifsc.razorpay.com/SBIN0011368
# https://ifsc.razorpay.com/SBIN0011367
# https://ifsc.razorpay.com/SBIN0011366
# https://ifsc.razorpay.com/SBIN0011365
# https://ifsc.razorpay.com/SBIN0011364
# https://ifsc.razorpay.com/SBIN0011363
# https://ifsc.razorpay.com/SBIN0011362
# https://ifsc.razorpay.com/SBIN0011361
# https://ifsc.razorpay.com/SBIN0011358
# https://ifsc.razorpay.com/SBIN0011357
# https://ifsc.razorpay.com/SBIN0011356
# https://ifsc.razorpay.com/SBIN0011355
# https://ifsc.razorpay.com/SBIN0011354
# https://ifsc.razorpay.com/SBIN0011353
# https://ifsc.razorpay.com/SBIN0011352
# https://ifsc.razorpay.com/SBIN0011351
# https://ifsc.razorpay.com/SBIN0011350
# https://ifsc.razorpay.com/SBIN0011349
# https://ifsc.razorpay.com/SBIN0011348
# https://ifsc.razorpay.com/SBIN0011347
# https://ifsc.razorpay.com/SBIN0011346
# https://ifsc.razorpay.com/SBIN0011345
# https://ifsc.razorpay.com/SBIN0011344
# https://ifsc.razorpay.com/SBIN0011343
# https://ifsc.razorpay.com/SBIN0011342
# https://ifsc.razorpay.com/SBIN0011340
# https://ifsc.razorpay.com/SBIN0011339
# https://ifsc.razorpay.com/SBIN0011338
# https://ifsc.razorpay.com/SBIN0011336
# https://ifsc.razorpay.com/SBIN0011335
# https://ifsc.razorpay.com/SBIN0011334
# https://ifsc.razorpay.com/SBIN0011333
# https://ifsc.razorpay.com/SBIN0011332
# https://ifsc.razorpay.com/SBIN0011331
# https://ifsc.razorpay.com/SBIN0011330
# https://ifsc.razorpay.com/SBIN0011329
# https://ifsc.razorpay.com/SBIN0011328
# https://ifsc.razorpay.com/SBIN0011327
# https://ifsc.razorpay.com/SBIN0011326
# https://ifsc.razorpay.com/SBIN0011325
# https://ifsc.razorpay.com/SBIN0011324
# https://ifsc.razorpay.com/SBIN0011323
# https://ifsc.razorpay.com/SBIN0011322
# https://ifsc.razorpay.com/SBIN0011321
# https://ifsc.razorpay.com/SBIN0011320
# https://ifsc.razorpay.com/SBIN0011319
# https://ifsc.razorpay.com/SBIN0011318
# https://ifsc.razorpay.com/SBIN0011317
# https://ifsc.razorpay.com/SBIN0011316
# https://ifsc.razorpay.com/SBIN0011315
# https://ifsc.razorpay.com/SBIN0011314
# https://ifsc.razorpay.com/SBIN0011313
# https://ifsc.razorpay.com/SBIN0011312
# https://ifsc.razorpay.com/SBIN0011311
# https://ifsc.razorpay.com/SBIN0011310
# https://ifsc.razorpay.com/SBIN0011309
# https://ifsc.razorpay.com/SBIN0011308
# https://ifsc.razorpay.com/SBIN0011307
# https://ifsc.razorpay.com/SBIN0011306
# https://ifsc.razorpay.com/SBIN0011305
# https://ifsc.razorpay.com/SBIN0011304
# https://ifsc.razorpay.com/SBIN0011303
# https://ifsc.razorpay.com/SBIN0011302
# https://ifsc.razorpay.com/SBIN0011301
# https://ifsc.razorpay.com/SBIN0011300
# https://ifsc.razorpay.com/SBIN0011299
# https://ifsc.razorpay.com/SBIN0011298
# https://ifsc.razorpay.com/SBIN0011297
# https://ifsc.razorpay.com/SBIN0011296
# https://ifsc.razorpay.com/SBIN0011295
# https://ifsc.razorpay.com/SBIN0011294
# https://ifsc.razorpay.com/SBIN0011293
# https://ifsc.razorpay.com/SBIN0011292
# https://ifsc.razorpay.com/SBIN0011291
# https://ifsc.razorpay.com/SBIN0011290
# https://ifsc.razorpay.com/SBIN0011289
# https://ifsc.razorpay.com/SBIN0011288
# https://ifsc.razorpay.com/SBIN0011287
# https://ifsc.razorpay.com/SBIN0011286
# https://ifsc.razorpay.com/SBIN0011285
# https://ifsc.razorpay.com/SBIN0011284
# https://ifsc.razorpay.com/SBIN0011283
# https://ifsc.razorpay.com/SBIN0011282
# https://ifsc.razorpay.com/SBIN0011281
# https://ifsc.razorpay.com/SBIN0011280
# https://ifsc.razorpay.com/SBIN0011279
# https://ifsc.razorpay.com/SBIN0011278
# https://ifsc.razorpay.com/SBIN0011277
# https://ifsc.razorpay.com/SBIN0011276
# https://ifsc.razorpay.com/SBIN0011275
# https://ifsc.razorpay.com/SBIN0011274
# https://ifsc.razorpay.com/SBIN0011273
# https://ifsc.razorpay.com/SBIN0011272
# https://ifsc.razorpay.com/SBIN0011271
# https://ifsc.razorpay.com/SBIN0011270
# https://ifsc.razorpay.com/SBIN0011269
# https://ifsc.razorpay.com/SBIN0011268
# https://ifsc.razorpay.com/SBIN0011267
# https://ifsc.razorpay.com/SBIN0011266
# https://ifsc.razorpay.com/SBIN0011265
# https://ifsc.razorpay.com/SBIN0011264
# https://ifsc.razorpay.com/SBIN0011263
# https://ifsc.razorpay.com/SBIN0011262
# https://ifsc.razorpay.com/SBIN0011261
# https://ifsc.razorpay.com/SBIN0011260
# https://ifsc.razorpay.com/SBIN0011259
# https://ifsc.razorpay.com/SBIN0011258
# https://ifsc.razorpay.com/SBIN0011257
# https://ifsc.razorpay.com/SBIN0011256
# https://ifsc.razorpay.com/SBIN0011254
# https://ifsc.razorpay.com/SBIN0011253
# https://ifsc.razorpay.com/SBIN0011252
# https://ifsc.razorpay.com/SBIN0011251
# https://ifsc.razorpay.com/SBIN0011250
# https://ifsc.razorpay.com/SBIN0011249
# https://ifsc.razorpay.com/SBIN0011248
# https://ifsc.razorpay.com/SBIN0011247
# https://ifsc.razorpay.com/SBIN0011246
# https://ifsc.razorpay.com/SBIN0011245
# https://ifsc.razorpay.com/SBIN0011244
# https://ifsc.razorpay.com/SBIN0011243
# https://ifsc.razorpay.com/SBIN0011242
# https://ifsc.razorpay.com/SBIN0011241
# https://ifsc.razorpay.com/SBIN0011240
# https://ifsc.razorpay.com/SBIN0011239
# https://ifsc.razorpay.com/SBIN0011238
# https://ifsc.razorpay.com/SBIN0011237
# https://ifsc.razorpay.com/SBIN0011236
# https://ifsc.razorpay.com/SBIN0011235
# https://ifsc.razorpay.com/SBIN0011234
# https://ifsc.razorpay.com/SBIN0011233
# https://ifsc.razorpay.com/SBIN0011232
# https://ifsc.razorpay.com/SBIN0011231
# https://ifsc.razorpay.com/SBIN0011230
# https://ifsc.razorpay.com/SBIN0011229
# https://ifsc.razorpay.com/SBIN0011228
# https://ifsc.razorpay.com/SBIN0011227
# https://ifsc.razorpay.com/SBIN0011226
# https://ifsc.razorpay.com/SBIN0011225
# https://ifsc.razorpay.com/SBIN0011224
# https://ifsc.razorpay.com/SBIN0011223
# https://ifsc.razorpay.com/SBIN0011222
# https://ifsc.razorpay.com/SBIN0011221
# https://ifsc.razorpay.com/SBIN0011220
# https://ifsc.razorpay.com/SBIN0011219
# https://ifsc.razorpay.com/SBIN0011218
# https://ifsc.razorpay.com/SBIN0011217
# https://ifsc.razorpay.com/SBIN0011216
# https://ifsc.razorpay.com/SBIN0011215
# https://ifsc.razorpay.com/SBIN0011214
# https://ifsc.razorpay.com/SBIN0011213
# https://ifsc.razorpay.com/SBIN0011212
# https://ifsc.razorpay.com/SBIN0011211
# https://ifsc.razorpay.com/SBIN0011210
# https://ifsc.razorpay.com/SBIN0011209
# https://ifsc.razorpay.com/SBIN0011208
# https://ifsc.razorpay.com/SBIN0011207
# https://ifsc.razorpay.com/SBIN0011206
# https://ifsc.razorpay.com/SBIN0011205
# https://ifsc.razorpay.com/SBIN0011204
# https://ifsc.razorpay.com/SBIN0011203
# https://ifsc.razorpay.com/SBIN0011202
# https://ifsc.razorpay.com/SBIN0011201
# https://ifsc.razorpay.com/SBIN0011200
# https://ifsc.razorpay.com/SBIN0011199
# https://ifsc.razorpay.com/SBIN0011198
# https://ifsc.razorpay.com/SBIN0011197
# https://ifsc.razorpay.com/SBIN0011196
# https://ifsc.razorpay.com/SBIN0011195
# https://ifsc.razorpay.com/SBIN0011194
# https://ifsc.razorpay.com/SBIN0011193
# https://ifsc.razorpay.com/SBIN0011192
# https://ifsc.razorpay.com/SBIN0011191
# https://ifsc.razorpay.com/SBIN0011190
# https://ifsc.razorpay.com/SBIN0011189
# https://ifsc.razorpay.com/SBIN0011188
# https://ifsc.razorpay.com/SBIN0011187
# https://ifsc.razorpay.com/SBIN0011186
# https://ifsc.razorpay.com/SBIN0011185
# https://ifsc.razorpay.com/SBIN0011184
# https://ifsc.razorpay.com/SBIN0011183
# https://ifsc.razorpay.com/SBIN0011182
# https://ifsc.razorpay.com/SBIN0011181
# https://ifsc.razorpay.com/SBIN0011180
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-108595b13949> in <module>
#     121
#     122
# --> 123 start(data,"sbi")
#     124
#     125
#
# <ipython-input-23-108595b13949> in start(list1, file_name)
#     112     print(bank['BANK'])
#     113     for url1 in list1:
# --> 114         complete.append(getToFile(url1,file_name))
#     115         with open("temp.json", 'w+') as outfile:
#     116           json.dump(complete, outfile, indent=4, sort_keys=True)
#
# <ipython-input-23-108595b13949> in getToFile(url, file_name)
#      97     url="https://ifsc.razorpay.com/"+url;
#      98     print(url)
# ---> 99     response=requests.get(url)
#     100     return response.json()
#     101
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379         # Trigger any extra validation we need to do.
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#     383             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     976         # Force connect early to allow us to validate the connection.
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#     980         if not conn.is_verified:
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     307     def connect(self):
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#     311
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     157
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72             if source_address:
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#      76
#
# KeyboardInterrupt:
