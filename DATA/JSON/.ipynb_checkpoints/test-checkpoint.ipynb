# %%
# Function to find all close matches of
# input string in given list of possible strings
from difflib import get_close_matches

def closeMatches(patterns, word):
    list=get_close_matches(word, patterns)
    print(list)

# Driver program
if __name__ == "__main__":
	word = 'appel'
	patterns = ['ape', 'apple', 'peach', 'puppy']
	closeMatches(patterns, word)
# Out:
# ['apple', 'ape']

# %%
import json,os
import xlwt
from xlwt import Workbook


def getList(file):
    f=open(file,"r")
    dt=f.read()
    j=json.loads(dt)
    dist_list=[]
    for i in j:
        dist_list.append(i["BRANCH"])
    ud=list(set(dist_list))
    fl=open("file.txt","a")
    j=json.dump(ud,fl)
   


    
for root, dirs, files in os.walk("C:\\Users\\Kaustubh\\Downloads\\JSON"):
    for file in files:
        if file.endswith('.json') :
            print(file)
            getList(file)
# Out:
# A.P. Mahesh Co-operative Urban Bank.json
# Abhyudaya Co-operative Bank.json
# Ahmedabad Mercantile Co-operative Bank.json
# Ahmednagar Merchants Co-operative Bank.json
# Airtel Payments Bank.json
# Ajara Urban Co-operative Bank.json
# Akola District Central Co-operative Bank.json
# Akola Janata Commercial Co-operative Bank.json
# ALLAHABAD_BANK.json
# Almora Urban Co-operative Bank.json
# Ambarnath Jaihind Co-operative Bank Ambarnath.json
# Andhra Bank.json
# Andhra Pradesh Grameena Vikas Bank.json
# Andhra Pragathi Grameena Bank.json
# Apna Sahakari Bank.json
# Arvind Sahakari Bank.json
# AU Small Finance Bank.json
# Australia and New Zealand Banking Group.json
# Axis Bank.json
# Bandhan Bank.json
# Bank of America.json
# Bank of Bahrein and Kuwait.json
# Bank of Baroda.json
# Bank of Ceylon.json
# Bank of India.json
# Bank Of Maharshtra.json
# Bank of Nova Scotia.json
# Baramati Sahakari Bank.json
# Barclays Bank.json
# Bassein Catholic Co-operative Bank.json
# ...
